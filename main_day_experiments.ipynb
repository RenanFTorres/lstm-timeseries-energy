# %% [markdown]
# ## **Importação das bibliotecas e dados (AEP e Duas Unas)**

# %%
# %pip install ipykernel --break-system-packages
# %pip install scikit-learn --break-system-packages
# %pip install matplotlib --break-system-packages
# %pip install keras --break-system-packages
# %pip install tensorflow --break-system-packages
# %pip install pandas --break-system-packages
# %pip install plotly --break-system-packages
# %pip install seaborn --break-system-packages
# %pip install nbformat --break-system-packages
# %pip install keras --break-system-packages

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error

from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from tensorflow.keras.initializers import GlorotUniform    #Inicializador de pesos
from sklearn.model_selection import KFold
from tensorflow.keras.optimizers import Adam

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf #Biblioteca para machine learning

# %%
base_path = './dataset/'

# carregando arquivo CSV
time_base = 'days'  # Escolha do tipo de agrupamento
duas_unas_dataset = f'{base_path}duas_unas/{time_base}/grouped_1_{time_base}.csv'  # Definição do caminho do diretório do dataset
print(len(duas_unas_dataset))
validation_interval = 97  # Definição da parcela dos dados que serão retiradas do treinamento/teste para validação
time_step = 1  # Number of previous time steps to consider
output_steps = 14  # Number of future steps to predict

# transformando CSV em DataFrame
duas_unas_df = pd.read_csv(duas_unas_dataset)  # Transformação em dataset

duas_unas_validation = duas_unas_df.tail(validation_interval)  # Criação do dataset de validação

indices_to_validate = duas_unas_df.index[-validation_interval:].tolist()  # Obtenção dos índices dos dadoss de validação
duas_unas_df = duas_unas_df.drop(indices_to_validate).reset_index(drop=True)  # Retirada dos dados de validação do dataset original de treino/teste

duas_unas_df['timestamp'] = pd.to_datetime(duas_unas_df['timestamp'])  # Transformação dos dados da coluna 'timestamp' no formato datetime. Ela lida com vários formatos de data/hora e tenta interpretá-los de forma inteligente.
duas_unas_validation['timestamp'] = pd.to_datetime(duas_unas_validation['timestamp'])  # Idem da ação da linha de cima.

duas_unas_df['index'] = range(len(duas_unas_df))  # Criação da coluna 'index' em que os valores vão de zero ao tamanho total do daframe
duas_unas_validation['index'] = indices_to_validate  # Idem da acima da linha acima
print(indices_to_validate)
duas_unas_df['kwh'] = duas_unas_df['kWh fornecido']  # Criação da coluna 'kwh' que copia os dados da coluna 'kWh fornecido'
duas_unas_validation['kwh'] = duas_unas_validation['kWh fornecido']  # Idem da acima da linha acima

duas_unas_df.drop(columns=['timestamp'], inplace=True)  # Remoção da coluna 'timestamp', inclusive no dataframe original
duas_unas_validation.drop(columns=['timestamp'], inplace=True)  # Idem da acima da linha acima

duas_unas_df.drop(columns=['kWh fornecido'], inplace=True)  # Remoção da coluna 'kWh fornecido', inclusive no dataframe original
duas_unas_validation.drop(columns=['kWh fornecido'], inplace=True)  # Idem da acima da linha acima

X = duas_unas_df['index'].values.reshape(-1,1)  # Cria o array X com os índices do dataframe duas_unas_df
y = duas_unas_df['kwh'].values  # Cria o array y com os dados de energia de duas_unas_df
#print(y)
X_validation = duas_unas_validation['index'].values.reshape(-1,1)  # Cria o array X_validation com os índices do dataframe duas_unas_validation
y_validation = duas_unas_validation['kwh'].values  # Cria o array y com os dados de energia de duas_unas_validation
#print(X_validation)
# Out:
# 43
# [214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310]

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# regr = MLPRegressor(hidden_layer_sizes=(50,50,50), max_iter=200).fit(X_train, y_train)

# y_pred = regr.predict(X_test)

# from sklearn.metrics import mean_squared_error

# rms = mean_squared_error(y_test, y_pred, squared=False)

# plt.figure(figsize=(8, 6))
# plt.scatter(X_test, y_test, color="blue", label="Valores Reais")
# plt.scatter(X_test, y_pred, color="red", label="Previsões", alpha=0.6)
# plt.title(f"Teste do MLPRegressor (RMSE: {rms:.2f})")
# plt.xlabel("Horas (X)")
# plt.ylabel("Previsão (y)")
# plt.legend()
# plt.show()

# %%
# print(X_validation)
# y_pred_validation = regr.predict(X_validation)

# plt.figure(figsize=(8, 6))
# plt.scatter(X_validation, y_validation, color="blue", label="Valores Reais")
# plt.scatter(X_validation, y_pred_validation, color="red", label="Previsões", alpha=0.6)
# plt.title(f"Hora da Verdade")
# plt.xlabel("Hora (X)")
# plt.ylabel("Consumo (y)")
# plt.legend()
# plt.show()

# %%
# pirapama_dataset = f'{base_path}outras_unidades/pirapama/agrupado_hora_Pirapama_2021.csv'
# # transformando CSV em DataFrame
# pirapama_df = pd.read_csv(pirapama_dataset)

# pirapama_df['Data'] = pd.to_datetime(pirapama_df['Data'])

# pirapama_df['index'] = range(len(pirapama_df))

# pirapama_df['kwh'] = pirapama_df['kWh fornecido'] 

# pirapama_df.drop(columns=['Data'], inplace=True)

# pirapama_df.drop(columns=['kWh fornecido'], inplace=True)

# X_pirapama = pirapama_df['index'].values.reshape(-1,1)
# y_pirapama = pirapama_df['kwh'].values

# y_pred = regr.predict(X_pirapama)

# plt.figure(figsize=(8, 6))
# plt.plot(X_pirapama, y_pirapama, color="blue", label="Valores Reais")
# plt.plot(X_pirapama, y_pred, color="red", label="Valores Previstos")
# plt.title(f"Hora da Verdade")
# plt.xlabel("Hora (X)")
# plt.ylabel("Consumo (y)")
# plt.legend()
# plt.show()

# %%
scaler = MinMaxScaler(feature_range=(0, 1))  # Padronização dos dados
scaled_kwh = scaler.fit_transform(duas_unas_df['kwh'].values.reshape(-1, 1))  # padronização de duas_unas_df

scaled_kwh_validation = scaler.fit_transform(duas_unas_validation['kwh'].values.reshape(-1,1))  # padronização de duas_unas_validacao

def create_dataset(data, time_step, output_steps):  # Função para construção do dataset
    X, y = [], []  # Criação das listas
    for i in range(len(data) - time_step - output_steps + 1):  # Loop
        X.append(data[i:(i + time_step), 0])  # Construção do dataset 
        y.append(data[(i + time_step):(i + time_step + output_steps), 0])
    return np.array(X), np.array(y)

# Create the dataset
X, y = create_dataset(scaled_kwh, time_step, output_steps)

X_validation, y_validation = create_dataset(scaled_kwh_validation, time_step, output_steps)

# Reshape input to be [samples, time steps, features]
X = X.reshape(X.shape[0], X.shape[1], 1)
X_validation = X_validation.reshape(X_validation.shape[0], X_validation.shape[1], 1)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)



# Build the LSTM model
model = Sequential()
model.add(LSTM(20, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(20, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(20, return_sequences=False))
model.add(Dropout(0.2))

model.add(Dense(output_steps)) 

learning_rate = 0.0005
optimizer = Adam(learning_rate=learning_rate)

model.compile(optimizer=optimizer, loss='mean_squared_error')

#callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.02, patience=2, verbose=0, mode='auto')
history = model.fit(X_train, y_train, epochs=100000, batch_size=30, validation_split=.2, callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', verbose=2, patience=3))

# Train the model
#history = model.fit(X_train, y_train, epochs=1000, batch_size=4, verbose=1, callbacks=tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2, verbose=1))

# Plotar as perdas de treinamento e validação
plt.plot(history.history['loss'], label='Loss de Treinamento')
plt.plot(history.history['val_loss'], label='Loss de Validação')
plt.xlabel('Épocas')
plt.ylabel('Perda')
plt.legend()
plt.show()
# Out:
# c:\Users\Renan Torres\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 15s 441ms/step - loss: 0.9077 - val_loss: 0.8931
# Epoch 2/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.9012 - val_loss: 0.8886
# Epoch 3/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.8980 - val_loss: 0.8840
# Epoch 4/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.8935 - val_loss: 0.8794
# Epoch 5/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.8921 - val_loss: 0.8748
# Epoch 6/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.8880 - val_loss: 0.8700
# Epoch 7/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.8813 - val_loss: 0.8652
# Epoch 8/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.8742 - val_loss: 0.8602
# Epoch 9/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.8718 - val_loss: 0.8552
# Epoch 10/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.8639 - val_loss: 0.8501
# Epoch 11/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.8597 - val_loss: 0.8448
# Epoch 12/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.8595 - val_loss: 0.8394
# Epoch 13/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.8487 - val_loss: 0.8339
# Epoch 14/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.8424 - val_loss: 0.8282
# Epoch 15/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.8369 - val_loss: 0.8223
# Epoch 16/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.8368 - val_loss: 0.8162
# Epoch 17/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.8254 - val_loss: 0.8099
# Epoch 18/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.8227 - val_loss: 0.8035
# Epoch 19/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.8122 - val_loss: 0.7968
# Epoch 20/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.8092 - val_loss: 0.7898
# Epoch 21/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.7969 - val_loss: 0.7826
# Epoch 22/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.7878 - val_loss: 0.7750
# Epoch 23/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.7871 - val_loss: 0.7672
# Epoch 24/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.7781 - val_loss: 0.7590
# Epoch 25/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.7672 - val_loss: 0.7505
# Epoch 26/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.7563 - val_loss: 0.7416
# Epoch 27/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.7472 - val_loss: 0.7322
# Epoch 28/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.7428 - val_loss: 0.7225
# Epoch 29/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.7325 - val_loss: 0.7123
# Epoch 30/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.7232 - val_loss: 0.7016
# Epoch 31/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.7156 - val_loss: 0.6905
# Epoch 32/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.6994 - val_loss: 0.6790
# Epoch 33/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.6879 - val_loss: 0.6668
# Epoch 34/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.6825 - val_loss: 0.6540
# Epoch 35/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.6570 - val_loss: 0.6404
# Epoch 36/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.6493 - val_loss: 0.6261
# Epoch 37/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.6327 - val_loss: 0.6112
# Epoch 38/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.6146 - val_loss: 0.5956
# Epoch 39/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.6122 - val_loss: 0.5794
# Epoch 40/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.5808 - val_loss: 0.5622
# Epoch 41/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.5609 - val_loss: 0.5443
# Epoch 42/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.5473 - val_loss: 0.5255
# Epoch 43/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.5158 - val_loss: 0.5058
# Epoch 44/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.5118 - val_loss: 0.4853
# Epoch 45/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.4894 - val_loss: 0.4641
# Epoch 46/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.4739 - val_loss: 0.4424
# Epoch 47/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.4430 - val_loss: 0.4201
# Epoch 48/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.4274 - val_loss: 0.3973
# Epoch 49/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.4009 - val_loss: 0.3743
# Epoch 50/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.3801 - val_loss: 0.3510
# Epoch 51/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.3571 - val_loss: 0.3277
# Epoch 52/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3347 - val_loss: 0.3043
# Epoch 53/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.3045 - val_loss: 0.2811
# Epoch 54/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.3107 - val_loss: 0.2583
# Epoch 55/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2734 - val_loss: 0.2362
# Epoch 56/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2514 - val_loss: 0.2149
# Epoch 57/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2289 - val_loss: 0.1944
# Epoch 58/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2145 - val_loss: 0.1750
# Epoch 59/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2099 - val_loss: 0.1569
# Epoch 60/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1786 - val_loss: 0.1402
# Epoch 61/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1744 - val_loss: 0.1250
# Epoch 62/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1439 - val_loss: 0.1114
# Epoch 63/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1364 - val_loss: 0.0993
# Epoch 64/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1341 - val_loss: 0.0887
# Epoch 65/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1111 - val_loss: 0.0797
# Epoch 66/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1091 - val_loss: 0.0720
# Epoch 67/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1118 - val_loss: 0.0653
# Epoch 68/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0856 - val_loss: 0.0595
# Epoch 69/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0922 - val_loss: 0.0546
# Epoch 70/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.1038 - val_loss: 0.0505
# Epoch 71/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0910 - val_loss: 0.0470
# Epoch 72/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0933 - val_loss: 0.0440
# Epoch 73/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0960 - val_loss: 0.0412
# Epoch 74/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0862 - val_loss: 0.0389
# Epoch 75/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0799 - val_loss: 0.0369
# Epoch 76/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0875 - val_loss: 0.0349
# Epoch 77/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0798 - val_loss: 0.0331
# Epoch 78/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0806 - val_loss: 0.0315
# Epoch 79/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0703 - val_loss: 0.0303
# Epoch 80/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0691 - val_loss: 0.0292
# Epoch 81/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0833 - val_loss: 0.0282
# Epoch 82/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0754 - val_loss: 0.0274
# Epoch 83/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0742 - val_loss: 0.0267
# Epoch 84/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0760 - val_loss: 0.0260
# Epoch 85/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0798 - val_loss: 0.0253
# Epoch 86/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0694 - val_loss: 0.0246
# Epoch 87/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0705 - val_loss: 0.0239
# Epoch 88/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0689 - val_loss: 0.0232
# Epoch 89/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0664 - val_loss: 0.0226
# Epoch 90/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0562 - val_loss: 0.0223
# Epoch 91/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0591 - val_loss: 0.0219
# Epoch 92/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0705 - val_loss: 0.0215
# Epoch 93/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0787 - val_loss: 0.0211
# Epoch 94/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0617 - val_loss: 0.0209
# Epoch 95/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0741 - val_loss: 0.0206
# Epoch 96/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0693 - val_loss: 0.0202
# Epoch 97/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0653 - val_loss: 0.0199
# Epoch 98/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0621 - val_loss: 0.0196
# Epoch 99/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0604 - val_loss: 0.0196
# Epoch 100/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0636 - val_loss: 0.0197
# Epoch 101/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0642 - val_loss: 0.0199
# Epoch 102/100000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0712 - val_loss: 0.0199
# Epoch 102: early stopping

# %%
def avaliacao_multistep(janela_real, janela_prevista):
    
    mae_med = 0
    mse_med = 0
    rmse_med = 0
    mape_med = 0
    acuracia_med = 0
    # Converte as listas para arrays NumPy
    #janela_real = np.array(janela_real)
    #janela_prevista = np.array(janela_prevista)
    print(len(janela_real[0]))
    
    for j in range(len(janela_prevista)):
        if len(janela_real) != len(janela_prevista):
            raise ValueError("As janelas reais e previstas devem ter o mesmo comprimento.")

        else:
        #r2 =  round(r2_score(janela_real, janela_prevista), 2)   # Relacionado à regressão linear dos valores verdadeiros. É calculado com base no erro quadrático residual e erro total. O valor pode ser interpretado como a proporção dos valores previstos que estão na linha criada pela regressão.
        #print("R^2 Score of LSTM model = ",r2)
        #print(" ")

            mae = round(mean_absolute_error(janela_real[j], janela_prevista[j]), 3) # Arredondamento com três casas decimais
            print("MAE(Erro absoluto médio) Score of LSTM model = ",mae)
            print(" ")

            mse = round(mean_squared_error(janela_real[j], janela_prevista[j]), 3)
            print("MSE(Erro quadrático médio) Score of LSTM model = ",mse)
            print(" ")
            
            rmse = round(np.sqrt(mse), 3)
            print("RMSE(Raiz do erro quadrático médio) Score of LSTM model = ",rmse)
            print(" ")

            mape = round(mean_absolute_percentage_error(janela_real[j], janela_prevista[j]), 2)
            print("MAPE(Erro percentual médio absoluto) Score of LSTM model = ",mape)
            print(" ")
            
            ### Cálculo da ACURÁCIA ###
            
            # Calcula a diferença percentual
            diferencas_percentuais = np.abs((np.array(janela_real[j]) - np.array(janela_prevista[j])) / np.array(janela_real[j]))

            # Conta quantas diferenças percentuais estão dentro da tolerância
            acertos = np.sum(diferencas_percentuais <= 0.05) #0.05 é a tolerância

            # Calcula a acurácia
            acuracia = acertos / len(janela_real[0])   
            acuracia = round(100 * acuracia, 2)
            
            print("Accuracy Score of LSTM model = ",acuracia)
            mae_med += mae
            mse_med += mse
            rmse_med += rmse
            mape_med += mape
            acuracia_med += acuracia
            
    mae_med /=(len(janela_prevista))
    mse_med /=(len(janela_prevista))
    rmse_med /=(len(janela_prevista))
    mape_med /=(len(janela_prevista))
    acuracia_med /=(len(janela_prevista))
    
    return mae_med, mse_med, rmse_med, mape_med, acuracia_med

# %%
y_pred = model.predict(X_validation)
print(len(X_validation), len(y_pred), len(X_validation[0]))
y_pred_rescaled = scaler.inverse_transform(y_pred)

y_test_rescaled = scaler.inverse_transform(y_validation)
indices_to_validate = indices_to_validate[:len(y_pred_rescaled)]
#indices_to_validate = indices_to_validate[:validation_interval]
print(indices_to_validate)

plt.figure(figsize=(8,6))
plt.plot(indices_to_validate, y_test_rescaled, label="Original", color='blue')
plt.plot(indices_to_validate, y_pred_rescaled, label="Predição", color='red')
plt.yticks(np.arange(0,25000,step=1000))
plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 498ms/step
# 83 83 1
# [214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296]

# %%
plt.figure(figsize=(8,6))
plt.plot(indices_to_validate[0:output_steps], y_test_rescaled[0], label="Original", color='blue')
plt.plot(indices_to_validate[0:output_steps], y_pred_rescaled[0], label="Predição", color='red')
plt.yticks(np.arange(0,25000,step=1000))
plt.show()

plt.figure(figsize=(8,6))
plt.plot(indices_to_validate[1:1+output_steps], y_test_rescaled[1], label="Original", color='blue')
plt.plot(indices_to_validate[1:1+output_steps], y_pred_rescaled[1], label="Predição", color='red')
plt.yticks(np.arange(0,25000,step=1000))
plt.show()


plt.figure(figsize=(8,6))
plt.plot(indices_to_validate[2:2+output_steps], y_test_rescaled[2], label="Original", color='blue')
plt.plot(indices_to_validate[2:2+output_steps], y_pred_rescaled[2], label="Predição", color='red')
plt.yticks(np.arange(0,25000,step=1000))
plt.show()


plt.figure(figsize=(8,6))
plt.plot(indices_to_validate[3:3+output_steps], y_test_rescaled[3], label="Original", color='blue')
plt.plot(indices_to_validate[3:3+output_steps], y_pred_rescaled[3], label="Predição", color='red')
plt.yticks(np.arange(0,25000,step=1000))
plt.show()


plt.figure(figsize=(8,6))
plt.plot(indices_to_validate[60:60+output_steps], y_test_rescaled[64], label="Original", color='blue')
plt.plot(indices_to_validate[60:60+output_steps], y_pred_rescaled[64], label="Predição", color='red')
plt.yticks(np.arange(0,25000,step=1000))
plt.show()

# %%
avaliacao_multistep(y_test_rescaled,y_pred_rescaled)
# Out:
# 14
# MAE(Erro absoluto médio) Score of LSTM model =  2304.72
#
# MSE(Erro quadrático médio) Score of LSTM model =  11771064.356
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  3430.898
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.17
#
# Accuracy Score of LSTM model =  14.29
# MAE(Erro absoluto médio) Score of LSTM model =  2402.009
#
# MSE(Erro quadrático médio) Score of LSTM model =  14704457.168
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  3834.639
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.18
#
# Accuracy Score of LSTM model =  21.43
# MAE(Erro absoluto médio) Score of LSTM model =  2301.036
#
# MSE(Erro quadrático médio) Score of LSTM model =  12252289.973
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  3500.327
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.17
#
# Accuracy Score of LSTM model =  21.43
# MAE(Erro absoluto médio) Score of LSTM model =  2421.29
#
# MSE(Erro quadrático médio) Score of LSTM model =  13252702.724
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  3640.426
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.18
#
# Accuracy Score of LSTM model =  14.29
# MAE(Erro absoluto médio) Score of LSTM model =  2466.179
#
# MSE(Erro quadrático médio) Score of LSTM model =  13484924.461
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  3672.183
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.18
#
# Accuracy Score of LSTM model =  7.14
# MAE(Erro absoluto médio) Score of LSTM model =  2136.67
#
# MSE(Erro quadrático médio) Score of LSTM model =  10611876.288
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  3257.587
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.15
#
# Accuracy Score of LSTM model =  14.29
# MAE(Erro absoluto médio) Score of LSTM model =  2311.99
#
# MSE(Erro quadrático médio) Score of LSTM model =  12329682.122
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  3511.365
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.17
#
# Accuracy Score of LSTM model =  7.14
# MAE(Erro absoluto médio) Score of LSTM model =  2237.804
#
# MSE(Erro quadrático médio) Score of LSTM model =  12878285.866
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  3588.633
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.16
#
# Accuracy Score of LSTM model =  7.14
# MAE(Erro absoluto médio) Score of LSTM model =  2193.217
#
# MSE(Erro quadrático médio) Score of LSTM model =  11767392.166
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  3430.363
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.16
#
# Accuracy Score of LSTM model =  14.29
# MAE(Erro absoluto médio) Score of LSTM model =  2139.39
#
# MSE(Erro quadrático médio) Score of LSTM model =  11606318.231
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  3406.805
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.15
#
# Accuracy Score of LSTM model =  14.29
# MAE(Erro absoluto médio) Score of LSTM model =  2112.507
#
# MSE(Erro quadrático médio) Score of LSTM model =  12107278.163
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  3479.551
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.15
#
# Accuracy Score of LSTM model =  21.43
# MAE(Erro absoluto médio) Score of LSTM model =  2056.138
#
# MSE(Erro quadrático médio) Score of LSTM model =  11995587.371
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  3463.465
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.15
#
# Accuracy Score of LSTM model =  28.57
# MAE(Erro absoluto médio) Score of LSTM model =  2011.148
#
# MSE(Erro quadrático médio) Score of LSTM model =  11730875.441
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  3425.037
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.15
#
# Accuracy Score of LSTM model =  28.57
# MAE(Erro absoluto médio) Score of LSTM model =  1959.106
#
# MSE(Erro quadrático médio) Score of LSTM model =  10906082.431
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  3302.436
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.14
#
# Accuracy Score of LSTM model =  42.86
# MAE(Erro absoluto médio) Score of LSTM model =  4434.694
#
# MSE(Erro quadrático médio) Score of LSTM model =  19800115.13
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  4449.732
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.2
#
# Accuracy Score of LSTM model =  0.0
# MAE(Erro absoluto médio) Score of LSTM model =  631.721
#
# MSE(Erro quadrático médio) Score of LSTM model =  519319.035
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  720.638
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.03
#
# Accuracy Score of LSTM model =  85.71
# MAE(Erro absoluto médio) Score of LSTM model =  626.366
#
# MSE(Erro quadrático médio) Score of LSTM model =  523879.607
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  723.795
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.03
#
# Accuracy Score of LSTM model =  85.71
# MAE(Erro absoluto médio) Score of LSTM model =  686.768
#
# MSE(Erro quadrático médio) Score of LSTM model =  559115.454
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  747.74
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.03
#
# Accuracy Score of LSTM model =  85.71
# MAE(Erro absoluto médio) Score of LSTM model =  605.166
#
# MSE(Erro quadrático médio) Score of LSTM model =  476068.154
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  689.977
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.03
#
# Accuracy Score of LSTM model =  92.86
# MAE(Erro absoluto médio) Score of LSTM model =  588.365
#
# MSE(Erro quadrático médio) Score of LSTM model =  447482.988
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  668.942
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.03
#
# Accuracy Score of LSTM model =  92.86
# MAE(Erro absoluto médio) Score of LSTM model =  543.318
#
# MSE(Erro quadrático médio) Score of LSTM model =  411874.28
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  641.774
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.02
#
# Accuracy Score of LSTM model =  92.86
# MAE(Erro absoluto médio) Score of LSTM model =  698.863
#
# MSE(Erro quadrático médio) Score of LSTM model =  590797.427
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  768.633
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.03
#
# Accuracy Score of LSTM model =  85.71
# MAE(Erro absoluto médio) Score of LSTM model =  618.097
#
# MSE(Erro quadrático médio) Score of LSTM model =  499153.79
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  706.508
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.03
#
# Accuracy Score of LSTM model =  85.71
# MAE(Erro absoluto médio) Score of LSTM model =  568.013
#
# MSE(Erro quadrático médio) Score of LSTM model =  420972.152
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  648.824
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.03
#
# Accuracy Score of LSTM model =  92.86
# MAE(Erro absoluto médio) Score of LSTM model =  595.544
#
# MSE(Erro quadrático médio) Score of LSTM model =  512933.921
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  716.194
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.03
#
# Accuracy Score of LSTM model =  85.71
# MAE(Erro absoluto médio) Score of LSTM model =  560.288
#
# MSE(Erro quadrático médio) Score of LSTM model =  489302.054
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  699.501
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.03
#
# Accuracy Score of LSTM model =  85.71
# MAE(Erro absoluto médio) Score of LSTM model =  547.883
#
# MSE(Erro quadrático médio) Score of LSTM model =  467408.974
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  683.673
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.02
#
# Accuracy Score of LSTM model =  85.71
# MAE(Erro absoluto médio) Score of LSTM model =  583.485
#
# MSE(Erro quadrático médio) Score of LSTM model =  546845.446
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  739.49
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.03
#
# Accuracy Score of LSTM model =  85.71
# MAE(Erro absoluto médio) Score of LSTM model =  652.481
#
# MSE(Erro quadrático médio) Score of LSTM model =  595876.572
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  771.93
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.03
#
# Accuracy Score of LSTM model =  78.57
# MAE(Erro absoluto médio) Score of LSTM model =  664.529
#
# MSE(Erro quadrático médio) Score of LSTM model =  703643.92
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  838.835
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.03
#
# Accuracy Score of LSTM model =  78.57
# MAE(Erro absoluto médio) Score of LSTM model =  625.975
#
# MSE(Erro quadrático médio) Score of LSTM model =  654825.046
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  809.213
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.03
#
# Accuracy Score of LSTM model =  78.57
# MAE(Erro absoluto médio) Score of LSTM model =  705.099
#
# MSE(Erro quadrático médio) Score of LSTM model =  773455.204
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  879.463
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.03
#
# Accuracy Score of LSTM model =  78.57
# MAE(Erro absoluto médio) Score of LSTM model =  735.847
#
# MSE(Erro quadrático médio) Score of LSTM model =  834316.963
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  913.41
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.03
#
# Accuracy Score of LSTM model =  71.43
# MAE(Erro absoluto médio) Score of LSTM model =  778.238
#
# MSE(Erro quadrático médio) Score of LSTM model =  838040.35
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  915.445
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.04
#
# Accuracy Score of LSTM model =  78.57
# MAE(Erro absoluto médio) Score of LSTM model =  802.776
#
# MSE(Erro quadrático médio) Score of LSTM model =  903202.521
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  950.37
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.04
#
# Accuracy Score of LSTM model =  71.43
# MAE(Erro absoluto médio) Score of LSTM model =  933.796
#
# MSE(Erro quadrático médio) Score of LSTM model =  1149785.889
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  1072.281
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.04
#
# Accuracy Score of LSTM model =  71.43
# MAE(Erro absoluto médio) Score of LSTM model =  764.458
#
# MSE(Erro quadrático médio) Score of LSTM model =  749986.283
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  866.017
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.03
#
# Accuracy Score of LSTM model =  85.71
# MAE(Erro absoluto médio) Score of LSTM model =  917.104
#
# MSE(Erro quadrático médio) Score of LSTM model =  1022209.476
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  1011.044
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.04
#
# Accuracy Score of LSTM model =  71.43
# MAE(Erro absoluto médio) Score of LSTM model =  734.677
#
# MSE(Erro quadrático médio) Score of LSTM model =  683996.405
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  827.041
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.03
#
# Accuracy Score of LSTM model =  92.86
# MAE(Erro absoluto médio) Score of LSTM model =  818.276
#
# MSE(Erro quadrático médio) Score of LSTM model =  805359.765
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  897.418
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.04
#
# Accuracy Score of LSTM model =  78.57
# MAE(Erro absoluto médio) Score of LSTM model =  778.659
#
# MSE(Erro quadrático médio) Score of LSTM model =  721248.511
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  849.264
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.04
#
# Accuracy Score of LSTM model =  85.71
# MAE(Erro absoluto médio) Score of LSTM model =  671.083
#
# MSE(Erro quadrático médio) Score of LSTM model =  561346.288
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  749.23
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.03
#
# Accuracy Score of LSTM model =  92.86
# MAE(Erro absoluto médio) Score of LSTM model =  835.659
#
# MSE(Erro quadrático médio) Score of LSTM model =  869385.201
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  932.408
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.04
#
# Accuracy Score of LSTM model =  71.43
# MAE(Erro absoluto médio) Score of LSTM model =  801.121
#
# MSE(Erro quadrático médio) Score of LSTM model =  792101.865
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  890.001
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.04
#
# Accuracy Score of LSTM model =  78.57
# MAE(Erro absoluto médio) Score of LSTM model =  706.516
#
# MSE(Erro quadrático médio) Score of LSTM model =  728890.029
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  853.751
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.03
#
# Accuracy Score of LSTM model =  78.57
# MAE(Erro absoluto médio) Score of LSTM model =  770.319
#
# MSE(Erro quadrático médio) Score of LSTM model =  801683.926
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  895.368
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.03
#
# Accuracy Score of LSTM model =  78.57
# MAE(Erro absoluto médio) Score of LSTM model =  795.214
#
# MSE(Erro quadrático médio) Score of LSTM model =  855937.157
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  925.169
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.04
#
# Accuracy Score of LSTM model =  71.43
# MAE(Erro absoluto médio) Score of LSTM model =  800.896
#
# MSE(Erro quadrático médio) Score of LSTM model =  919327.5
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  958.816
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.04
#
# Accuracy Score of LSTM model =  64.29
# MAE(Erro absoluto médio) Score of LSTM model =  832.055
#
# MSE(Erro quadrático médio) Score of LSTM model =  966371.527
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  983.042
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.04
#
# Accuracy Score of LSTM model =  64.29
# MAE(Erro absoluto médio) Score of LSTM model =  1114.953
#
# MSE(Erro quadrático médio) Score of LSTM model =  4332588.258
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  2081.487
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.06
#
# Accuracy Score of LSTM model =  78.57
# MAE(Erro absoluto médio) Score of LSTM model =  1717.261
#
# MSE(Erro quadrático médio) Score of LSTM model =  6977570.268
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  2641.509
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.1
#
# Accuracy Score of LSTM model =  35.71
# MAE(Erro absoluto médio) Score of LSTM model =  1323.38
#
# MSE(Erro quadrático médio) Score of LSTM model =  4854991.167
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  2203.404
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.07
#
# Accuracy Score of LSTM model =  64.29
# MAE(Erro absoluto médio) Score of LSTM model =  1530.889
#
# MSE(Erro quadrático médio) Score of LSTM model =  5561559.584
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  2358.296
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.08
#
# Accuracy Score of LSTM model =  50.0
# MAE(Erro absoluto médio) Score of LSTM model =  1563.42
#
# MSE(Erro quadrático médio) Score of LSTM model =  5931272.04
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  2435.42
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.09
#
# Accuracy Score of LSTM model =  50.0
# MAE(Erro absoluto médio) Score of LSTM model =  1534.218
#
# MSE(Erro quadrático médio) Score of LSTM model =  5257633.836
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  2292.953
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.08
#
# Accuracy Score of LSTM model =  57.14
# MAE(Erro absoluto médio) Score of LSTM model =  1574.933
#
# MSE(Erro quadrático médio) Score of LSTM model =  5760803.309
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  2400.167
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.09
#
# Accuracy Score of LSTM model =  50.0
# MAE(Erro absoluto médio) Score of LSTM model =  1912.381
#
# MSE(Erro quadrático médio) Score of LSTM model =  7534294.326
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  2744.867
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.1
#
# Accuracy Score of LSTM model =  42.86
# MAE(Erro absoluto médio) Score of LSTM model =  1532.524
#
# MSE(Erro quadrático médio) Score of LSTM model =  5738438.961
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  2395.504
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.09
#
# Accuracy Score of LSTM model =  42.86
# MAE(Erro absoluto médio) Score of LSTM model =  1649.939
#
# MSE(Erro quadrático médio) Score of LSTM model =  6054075.136
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  2460.503
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.09
#
# Accuracy Score of LSTM model =  42.86
# MAE(Erro absoluto médio) Score of LSTM model =  1708.597
#
# MSE(Erro quadrático médio) Score of LSTM model =  6561532.704
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  2561.549
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.09
#
# Accuracy Score of LSTM model =  35.71
# MAE(Erro absoluto médio) Score of LSTM model =  2077.578
#
# MSE(Erro quadrático médio) Score of LSTM model =  8519036.936
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  2918.739
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.12
#
# Accuracy Score of LSTM model =  28.57
# MAE(Erro absoluto médio) Score of LSTM model =  2210.188
#
# MSE(Erro quadrático médio) Score of LSTM model =  9837464.2
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  3136.473
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.13
#
# Accuracy Score of LSTM model =  35.71
# MAE(Erro absoluto médio) Score of LSTM model =  2064.172
#
# MSE(Erro quadrático médio) Score of LSTM model =  7863384.143
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  2804.173
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.12
#
# Accuracy Score of LSTM model =  35.71
# MAE(Erro absoluto médio) Score of LSTM model =  3242.108
#
# MSE(Erro quadrático médio) Score of LSTM model =  11896845.808
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  3449.18
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.15
#
# Accuracy Score of LSTM model =  14.29
# MAE(Erro absoluto médio) Score of LSTM model =  1612.227
#
# MSE(Erro quadrático médio) Score of LSTM model =  4172410.431
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  2042.648
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.08
#
# Accuracy Score of LSTM model =  35.71
# MAE(Erro absoluto médio) Score of LSTM model =  1582.858
#
# MSE(Erro quadrático médio) Score of LSTM model =  3920553.245
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  1980.039
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.08
#
# Accuracy Score of LSTM model =  35.71
# MAE(Erro absoluto médio) Score of LSTM model =  1733.112
#
# MSE(Erro quadrático médio) Score of LSTM model =  4694433.489
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  2166.664
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.09
#
# Accuracy Score of LSTM model =  42.86
# MAE(Erro absoluto médio) Score of LSTM model =  1736.412
#
# MSE(Erro quadrático médio) Score of LSTM model =  5016846.539
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  2239.832
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.09
#
# Accuracy Score of LSTM model =  28.57
# MAE(Erro absoluto médio) Score of LSTM model =  1466.386
#
# MSE(Erro quadrático médio) Score of LSTM model =  3800705.082
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  1949.54
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.07
#
# Accuracy Score of LSTM model =  42.86
# MAE(Erro absoluto médio) Score of LSTM model =  2239.066
#
# MSE(Erro quadrático médio) Score of LSTM model =  5732251.278
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  2394.212
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.11
#
# Accuracy Score of LSTM model =  0.0
# MAE(Erro absoluto médio) Score of LSTM model =  1597.165
#
# MSE(Erro quadrático médio) Score of LSTM model =  4461823.337
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  2112.303
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.08
#
# Accuracy Score of LSTM model =  42.86
# MAE(Erro absoluto médio) Score of LSTM model =  1700.017
#
# MSE(Erro quadrático médio) Score of LSTM model =  4461020.304
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  2112.113
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.08
#
# Accuracy Score of LSTM model =  21.43
# MAE(Erro absoluto médio) Score of LSTM model =  1773.89
#
# MSE(Erro quadrático médio) Score of LSTM model =  4622826.203
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  2150.076
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.09
#
# Accuracy Score of LSTM model =  28.57
# MAE(Erro absoluto médio) Score of LSTM model =  2105.638
#
# MSE(Erro quadrático médio) Score of LSTM model =  5253322.223
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  2292.013
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.1
#
# Accuracy Score of LSTM model =  7.14
# MAE(Erro absoluto médio) Score of LSTM model =  2884.288
#
# MSE(Erro quadrático médio) Score of LSTM model =  9054477.383
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  3009.066
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.13
#
# Accuracy Score of LSTM model =  7.14
# MAE(Erro absoluto médio) Score of LSTM model =  1316.825
#
# MSE(Erro quadrático médio) Score of LSTM model =  2114650.076
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  1454.184
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.06
#
# Accuracy Score of LSTM model =  35.71
# MAE(Erro absoluto médio) Score of LSTM model =  1226.636
#
# MSE(Erro quadrático médio) Score of LSTM model =  1747336.201
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  1321.868
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.05
#
# Accuracy Score of LSTM model =  42.86
# MAE(Erro absoluto médio) Score of LSTM model =  1230.696
#
# MSE(Erro quadrático médio) Score of LSTM model =  1842621.525
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  1357.432
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.05
#
# Accuracy Score of LSTM model =  42.86
# MAE(Erro absoluto médio) Score of LSTM model =  1342.034
#
# MSE(Erro quadrático médio) Score of LSTM model =  2110884.297
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  1452.888
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.06
#
# Accuracy Score of LSTM model =  28.57
# MAE(Erro absoluto médio) Score of LSTM model =  1270.617
#
# MSE(Erro quadrático médio) Score of LSTM model =  1920420.093
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  1385.792
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.06
#
# Accuracy Score of LSTM model =  35.71
# MAE(Erro absoluto médio) Score of LSTM model =  1257.724
#
# MSE(Erro quadrático médio) Score of LSTM model =  1887281.355
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  1373.784
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.06
#
# Accuracy Score of LSTM model =  35.71
# MAE(Erro absoluto médio) Score of LSTM model =  1177.712
#
# MSE(Erro quadrático médio) Score of LSTM model =  1643639.412
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  1282.045
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.05
#
# Accuracy Score of LSTM model =  35.71
# MAE(Erro absoluto médio) Score of LSTM model =  1920.946
#
# MSE(Erro quadrático médio) Score of LSTM model =  4097617.578
#
# RMSE(Raiz do erro quadrático médio) Score of LSTM model =  2024.257
#
# MAPE(Erro percentual médio absoluto) Score of LSTM model =  0.09
#
# Accuracy Score of LSTM model =  14.29
# (1414.425819277108,
#  4696767.3047951795,
#  1883.4172530120486,
#  0.07843373493975894,
#  51.204457831325314)
